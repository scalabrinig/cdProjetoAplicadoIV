# %% [markdown]
# <a href="https://colab.research.google.com/github/scalabrinig/cdProjetoAplicadoIV/blob/master/projeto/cd_projeto_aplicado_IV_doc.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
#   <img src="https://raw.githubusercontent.com/scalabrinig/cdProjetoAplicadoIV/d093146488f56dfcf0ef286bcee8efe0e71b9c76/figuras/mackenzie_logo.jpg" width="25%" align="right"/>
#
# # **PROJETO APLICADO IV - Ciência de Dados EaD - 2026/02**
#
#
# # **Documentação do Projeto**
#
# ---

# %% [markdown]
# # **Título do Projeto**
# ---

# %%
#@title **Identificação do Grupo**

#@markdown Integrantes do Grupo, nome completo em ordem alfabética (*informe: \<nome\>, \<matrícula\>*)
Aluno1 = 'Aluno 1, 123456789' #@param {type:"string"}
Aluno2 = 'Aluno 2, 123456789' #@param {type:"string"}
Aluno3 = 'Aluno 3, 123456789' #@param {type:"string"}
Aluno4 = 'Aluno 4, 123456789' #@param {type:"string"}
Aluno5 = 'Aluno 5, 123456789' #@param {type:"string"}

# %% [markdown]
# # **Resumo**
#
# Um parágrafo no modelo de um resumo de artigo, indicando o problema que o projeto se propõe a resolver, sua relevância, o tipo de metodologia (técnicas, algoritmos, métodos, produto gerado - previsão, detecção de anomalia etc.) que foi aplicada para a solução e o principal resultado alcançado.

# %% [markdown]
# # **Introdução**
#
# Juntar os tópicos de contexto, motivação, objetivo geral, objetivos específicos (incluir a bases de dados que será explorada) e justificativa em um único tópico.

# %% [markdown]
# # **Referencial Teórico**
#
# (1 página) Definir resumidamente os principais conceitos envolvidos na sua solução. Discutir os trabalhos correlacionados. Apresentar alternativas de solução que foram empregadas no mesmo problema ou problemas semelhantes, e suas vantagens e limitações. Indicar referências ao longo do texto (padrão ABNT).

# %% [markdown]
# # **Diagrama de Solução**
#
# Apresente e discuta o diagrama final da solução proposta.

# %% [markdown]
# # **EDA e Pré-processamento dos dados**
#
# Exploração e análise dos dados. Discussão e análise dos dados empregados (qualidade, limitações, simplificações ou recortes adotados etc.). Tarefas de preparação dos dados (transformações, compactação e encodes, junções de dados etc.).

# %%
# Códigos aqui

# %% [markdown]
# # **Modelos**
#
# Descrição metodológica para a criação, refinamento e validação dos modelos propostos.

# %%
# Códigos aqui

# %% [markdown]
# # **Resultados**
#
# Apresentar os resultados obtidos, métricas, tabelas comparativas, etc.

# %% [markdown]
# # **Dicussão e Conclusão**
#
# Conclusões; análise crítica dos resultados do trabalho (suas qualidades e limitações); alcance do objetivo inicial (a solução do problema); potenciais melhorias no projeto.

# %% [markdown]
# # **Apresentação**
#
# Colocar os links do vídeo (apresentação com apoio de slides).

# %% [markdown]
# # **Referências**
#
# Referências bibliográficas (ABNT).
