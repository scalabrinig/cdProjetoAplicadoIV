# %% [markdown]
# <a href="https://colab.research.google.com/github/scalabrinig/cdProjetoAplicadoIV/blob/master/projeto/cd_projeto_aplicado_IV_entrega_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
#   <img src="https://raw.githubusercontent.com/scalabrinig/cdProjetoAplicadoIV/d093146488f56dfcf0ef286bcee8efe0e71b9c76/figuras/mackenzie_logo.jpg" width="25%" align="right"/>
#
# # **PROJETO APLICADO IV - Ciência de Dados EaD - 2024/02**
#
#
# # **Entrega 2**
#
# ---

# %% [markdown]
# # **Titulo do Projeto**:
#
# ---

# %%
#@title **Identificação do Grupo e Opção do Projeto**

#@markdown Integrantes do Grupo, nome completo em ordem alfabética (*informe: \<nome\>, \<matrícula\>*)
Aluno1 = 'Aluno 1, 123456789' #@param {type:"string"}
Aluno2 = 'Aluno 2, 159327486' #@param {type:"string"}
Aluno3 = 'Aluno 3, 987654321' #@param {type:"string"}
Aluno4 = 'Aluno 4, 753645987' #@param {type:"string"}
Aluno5 = 'Aluno 5, 456789123' #@param {type:"string"}

# %% [markdown]
# # **Introdução**
#
# Juntar os tópicos de contexto, motivação, objetivo geral, objetivos específicos (incluir a bases de dados que será explorada) e justificativa em um único tópico.

# %% [markdown]
# # **Referencial Teórico**
#
# (1 página) Defir resumidamente os principais conceitos envolvidos na sua solução. Discutir os trabalhos correlacionados. Apresentar alternativas de solução que foram empregadas no mesmo problema ou problemas semelhantes, e suas vantagens e limitações. Indicar referências ao longo do texto (padrão ABNT).

# %% [markdown]
# # **Pipeline da Solução**
#
# Apresentar e discutir uma proposta de pipeline para processar os dados e chegar na solução do problema em análise.

# %% [markdown]
# # **Cronograma**
#
# Apresentar a descrição das principais atividades de desenvolvimento e as datas para a entrega que cada atividade. Podem ser utilizadas como base as tarefas levantadas e descritas no pipeline de solução. Não esquecer das atividades relacionadas com a documentação.

# %% [markdown]
# # **Referências**
#
# Expor a relação dos recursos utilizados na elaboração do documento, desde que tenham sido devidamente citados. Para isso, devem ser utilizadas as normas da ABNT.

# %%
#@title **Avaliação**
Referencial_teorico = 10 #@param {type:"slider", min:0, max:10, step:1}

Pipeline_solucao = 10 #@param {type:"slider", min:0, max:10, step:1}

Cronograma = 10 #@param {type:"slider", min:0, max:10, step:1}

# %%
#@title **Nota Final**
nota = 0.40*Referencial_teorico + 0.40*Pipeline_solucao + 0.20*Cronograma

print(f'Nota final do trabalho {nota :.1f}')

import numpy as np
import pandas as pd

alunos = pd.DataFrame()

lista_nome = []

for i in range(1,6):
  exec("if Aluno" + str(i) + " !='None':  lista = Aluno" + str(i) + ".split(','); lista_nome.append(lista[0]);")

alunos['nome'] = lista_nome
alunos['nota'] = np.round(nota,1)
print()
display(alunos)
# Out:
# Nota final do trabalho 10.0
#       nome  nota
# 0  Aluno 1  10.0
# 1  Aluno 2  10.0
# 2  Aluno 3  10.0
# 3  Aluno 4  10.0
# 4  Aluno 5  10.0
